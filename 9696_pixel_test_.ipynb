# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# /
# Mounted at /content/gdrive

# %%
import cv2
import matplotlib.pyplot as plt

# %%
def img_show(title='image', img=None, figsize=(8 ,5)):
    plt.figure(figsize=figsize)
 
    if type(img) == list:
        if type(title) == list:
            titles = title
        else:
            titles = []
 
            for i in range(len(img)):
                titles.append(title)
 
        for i in range(len(img)):
            if len(img[i].shape) <= 2:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)
 
            plt.subplot(1, len(img), i + 1), plt.imshow(rgbImg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])
 
        plt.show()
    else:
        if len(img.shape) < 3:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
        plt.imshow(rgbImg)
        plt.title(title)
        plt.xticks([]), plt.yticks([])
        plt.show()

# %%
cv2_image = cv2.imread('/content/gdrive/MyDrive/IMG_0981123.JPG', cv2.IMREAD_COLOR)

# %%
(h, w) = cv2_image.shape[:2]
img_show("Original", cv2_image)
 
print('이미지 사이즈 : {}'.format(cv2_image.shape))
print('이미지 dtype : {}'.format(cv2_image.dtype))
print('이미지 Height : {}'.format(cv2_image.shape[0]))
print('이미지 Width : {}'.format(cv2_image.shape[1]))
print('이미지 전체 픽셀 개수 : {}'.format(cv2_image.size))
# Out:
# 이미지 사이즈 : (1202, 1284, 3)
# 이미지 dtype : uint8
# 이미지 Height : 1202
# 이미지 Width : 1284
# 이미지 전체 픽셀 개수 : 4630104

# %%
cv2_image = cv2.imread('/content/gdrive/MyDrive/IMG_0981123.JPG', cv2.IMREAD_COLOR)

# %%
(x,y), (w,h) = (300,50),(603,392)
roi_img = cv2_image[y:y+h, x:x+w]

# %%
cv2.rectangle(cv2_image, (x,y,w,h), 255, 3)
test1 = img_show("labeling",cv2_image)
test1
print('box size : {}'.format(roi_img.shape))
# Out:
# box size : (392, 603, 3)

# %%
cv3_image = cv2.imread('/content/gdrive/MyDrive/IMG_097211.jpg', cv2.IMREAD_COLOR)

# %%
(x,y), (w,h) = (300,30),(791,398)
roi_img = cv3_image[y:y+h, x:x+w]

# %%
cv2.rectangle(cv3_image, (x,y,w,h), 255, 5)
test2= img_show("labeling",cv3_image)
test2
print('box size : {}'.format(roi_img.shape))
# Out:
# box size : (398, 791, 3)

# %%
cv4_image = cv2.imread('/content/gdrive/MyDrive/IMG_0973.jpg', cv2.IMREAD_COLOR)

# %%
(x,y), (w,h) = (450,30),(791,551)
roi_img = cv4_image[y:y+h, x:x+w]

# %%
cv2.rectangle(cv4_image, (x,y,w,h), 255, 5)
test2= img_show("labeling",cv4_image)
test2
print('box size : {}'.format(roi_img.shape))
# Out:
# box size : (551, 791, 3)

# %%
cv5_image = cv2.imread('/content/gdrive/MyDrive/zzas123.JPG', cv2.IMREAD_COLOR)

# %%
(x,y), (w,h) = (450,70),(131,112)
roi_img = cv5_image[y:y+h, x:x+w]

# %%
cv2.rectangle(cv5_image, (x,y,w,h), 255, 5)
test2= img_show("labeling",cv5_image)
test2
print('box size : {}'.format(roi_img.shape))
# Out:
# box size : (112, 131, 3)

# %%
# 이미지의 중심을 계산
#(bX, bY) = (w//1, h//3)
bX = w//2
bY = h//2
bC = bX//3
# 이미지의 왼쪽 상단 모서리 (y1:y2, x1:x2)
tl = cv2_image[0:bC, 0:bY]
img_show("Top-Left Corner", tl)
print('Img size : {}'.format(tl.shape))
# Out:
# Img size : (214, 601, 3)

# %%
t2 = cv2_image[0:bX, 0:bC]
img_show(["Top-Right Corner", "Bottom-Right Corner"], [tl,t2])
